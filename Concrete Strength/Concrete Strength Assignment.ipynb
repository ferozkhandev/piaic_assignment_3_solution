# %% [markdown]
# # Assignment: Compresive Strength Concrete Problem
#
#
# ### Abstract:
#
# Concrete is the most important material in civil engineering. The concrete compressive strength (concrete strength to bear the load) is a highly nonlinear function of age and ingredients.  <br><br>
#
# <table border="1"  cellpadding="6" bordercolor="red">
# 	<tbody>
#         <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Data Set Characteristics:&nbsp;&nbsp;</b></p></td>
# 		<td><p class="normal">Multivariate</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Instances:</b></p></td>
# 		<td><p class="normal">1030</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Area:</b></p></td>
# 		<td><p class="normal">Physical</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#         <tr>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Attribute Characteristics:</b></p></td>
#             <td><p class="normal">Real</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Number of Attributes:</b></p></td>
#             <td><p class="normal">9</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Date Donated</b></p></td>
#             <td><p class="normal">2007-08-03</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#     <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Associated Tasks:</b></p></td>
# 		<td><p class="normal">Regression</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Missing Values?</b></p></td>
# 		<td><p class="normal">N/A</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Web Hits:</b></p></td>
# 		<td><p class="normal">231464</p></td>
# 	</tr>
#     </tbody>
#     </table>

# %% [markdown]
# ###  Description:
# | Features Name | Data Type | Measurement | Description |
# | -- | -- | -- | -- |
# Cement (component 1) | quantitative | kg in a m3 mixture | Input Variable
# Blast Furnace Slag (component 2) | quantitative | kg in a m3 mixture | Input Variable
# Fly Ash (component 3) | quantitative | kg in a m3 mixture | Input Variable
# Water (component 4) | quantitative | kg in a m3 mixture | Input Variable
# Superplasticizer (component 5) | quantitative | kg in a m3 mixture | Input Variable
# Coarse Aggregate (component 6) | quantitative | kg in a m3 mixture | Input Variable
# Fine Aggregate (component 7) | quantitative | kg in a m3 mixture | Input Variable
# Age | quantitative | Day (1~365) | Input Variable
# Concrete compressive strength | quantitative | MPa | Output Variable
#
# ### WORKFLOW :
# - Load Data
# - Check Missing Values ( If Exist ; Fill each record with mean of its feature )
# - Standardized the Input Variables. **Hint**: Centeralized the data
# - Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).
# - Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).
# - Compilation Step (Note : Its a Regression problem , select loss , metrics according to it)
# - Train the Model with Epochs (100) and validate it
# - If the model gets overfit tune your model by changing the units , No. of layers , activation function , epochs , add dropout layer or add Regularizer according to the need .
# - Evaluation Step
# - Prediction

# %% [markdown]
# # Load Data:
# [Click Here to Download DataSet](https://github.com/ramsha275/ML_Datasets/blob/main/compresive_strength_concrete.csv)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
df = pd.read_csv("/content/compresive_strength_concrete.csv")
df.head()
# Out:
#    Cement (component 1)(kg in a m^3 mixture)  ...  Concrete compressive strength(MPa, megapascals)
# 0                                      540.0  ...                                             79.99
# 1                                      540.0  ...                                             61.89
# 2                                      332.5  ...                                             40.27
# 3                                      332.5  ...                                             41.05
# 4                                      198.6  ...                                             44.30
#
# [5 rows x 9 columns]

# %%
df.fillna(df.mean())
# Out:
#       Cement (component 1)(kg in a m^3 mixture)  ...  Concrete compressive strength(MPa, megapascals)
# 0                                         540.0  ...                                             79.99
# 1                                         540.0  ...                                             61.89
# 2                                         332.5  ...                                             40.27
# 3                                         332.5  ...                                             41.05
# 4                                         198.6  ...                                             44.30
# ...                                         ...  ...                                               ...
# 1025                                      276.4  ...                                             44.28
# 1026                                      322.2  ...                                             31.18
# 1027                                      148.5  ...                                             23.70
# 1028                                      159.1  ...                                             32.77
# 1029                                      260.9  ...                                             32.40
#
# [1030 rows x 9 columns]

# %%
df.columns = ["cement", "bfs", "fly_ash", "water", "superplasticizer", "coarse_aggregate", "fine_aggregate", "age", "ccs"]
df
# Out:
#       cement    bfs  fly_ash  ...  fine_aggregate  age    ccs
# 0      540.0    0.0      0.0  ...           676.0   28  79.99
# 1      540.0    0.0      0.0  ...           676.0   28  61.89
# 2      332.5  142.5      0.0  ...           594.0  270  40.27
# 3      332.5  142.5      0.0  ...           594.0  365  41.05
# 4      198.6  132.4      0.0  ...           825.5  360  44.30
# ...      ...    ...      ...  ...             ...  ...    ...
# 1025   276.4  116.0     90.3  ...           768.3   28  44.28
# 1026   322.2    0.0    115.6  ...           813.4   28  31.18
# 1027   148.5  139.4    108.6  ...           780.0   28  23.70
# 1028   159.1  186.7      0.0  ...           788.9   28  32.77
# 1029   260.9  100.5     78.3  ...           761.5   28  32.40
#
# [1030 rows x 9 columns]

# %%
y = df['ccs']
df.drop('ccs', axis =1, inplace = True)
x = df.copy()

# %%
y.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: ccs, dtype: float64

# %%
x.head()
# Out:
#    cement    bfs  fly_ash  ...  coarse_aggregate  fine_aggregate  age
# 0   540.0    0.0      0.0  ...            1040.0           676.0   28
# 1   540.0    0.0      0.0  ...            1055.0           676.0   28
# 2   332.5  142.5      0.0  ...             932.0           594.0  270
# 3   332.5  142.5      0.0  ...             932.0           594.0  365
# 4   198.6  132.4      0.0  ...             978.4           825.5  360
#
# [5 rows x 8 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3)

# %%
print(df.shape)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1030, 8)
# (721, 8)
# (721,)
# (309, 8)
# (309,)

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train,y_train, test_size=0.2)

# %%
print(df.shape)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
print(x_val.shape)
print(y_val.shape)
# Out:
# (1030, 8)
# (576, 8)
# (576,)
# (309, 8)
# (309,)
# (145, 8)
# (145,)

# %%
model = Sequential()
model.add(Dense(10, activation='relu', input_shape=(x_train.shape)))
model.add(Dense(8, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(1))

# %%
model.compile('Adam', loss='mse', metrics='mae')

# %%
model.fit(x_train, y_train, epochs=100, verbose=1, validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# WARNING:tensorflow:Model was constructed with shape (None, 576, 8) for input KerasTensor(type_spec=TensorSpec(shape=(None, 576, 8), dtype=tf.float32, name='dense_1_input'), name='dense_1_input', description="created by layer 'dense_1_input'"), but it was called on an input with incompatible shape (32, 8).
# WARNING:tensorflow:Model was constructed with shape (None, 576, 8) for input KerasTensor(type_spec=TensorSpec(shape=(None, 576, 8), dtype=tf.float32, name='dense_1_input'), name='dense_1_input', description="created by layer 'dense_1_input'"), but it was called on an input with incompatible shape (32, 8).
#  1/18 [>.............................] - ETA: 6s - loss: 48.1382 - mae: 5.2713WARNING:tensorflow:Model was constructed with shape (None, 576, 8) for input KerasTensor(type_spec=TensorSpec(shape=(None, 576, 8), dtype=tf.float32, name='dense_1_input'), name='dense_1_input', description="created by layer 'dense_1_input'"), but it was called on an input with incompatible shape (None, 8).
# 18/18 [==============================] - 1s 13ms/step - loss: 51.7877 - mae: 5.5719 - val_loss: 60.5762 - val_mae: 5.7145
# Epoch 2/100
# 18/18 [==============================] - 0s 4ms/step - loss: 52.5096 - mae: 5.5496 - val_loss: 62.6286 - val_mae: 5.7960
# Epoch 3/100
# 18/18 [==============================] - 0s 4ms/step - loss: 53.6371 - mae: 5.6495 - val_loss: 58.4976 - val_mae: 5.6601
# Epoch 4/100
# 18/18 [==============================] - 0s 4ms/step - loss: 50.9025 - mae: 5.5005 - val_loss: 66.9312 - val_mae: 6.0586
# Epoch 5/100
# 18/18 [==============================] - 0s 4ms/step - loss: 59.5739 - mae: 5.8709 - val_loss: 58.1620 - val_mae: 5.6384
# Epoch 6/100
# 18/18 [==============================] - 0s 4ms/step - loss: 58.0142 - mae: 5.8992 - val_loss: 64.1140 - val_mae: 5.9040
# Epoch 7/100
# 18/18 [==============================] - 0s 4ms/step - loss: 54.9264 - mae: 5.6878 - val_loss: 58.2866 - val_mae: 5.5881
# Epoch 8/100
# 18/18 [==============================] - 0s 4ms/step - loss: 53.1041 - mae: 5.6077 - val_loss: 64.5598 - val_mae: 6.1543
# Epoch 9/100
# 18/18 [==============================] - 0s 4ms/step - loss: 56.5685 - mae: 6.0381 - val_loss: 61.8171 - val_mae: 5.7868
# Epoch 10/100
# 18/18 [==============================] - 0s 4ms/step - loss: 52.4289 - mae: 5.4991 - val_loss: 57.3923 - val_mae: 5.5704
# Epoch 11/100
# 18/18 [==============================] - 0s 4ms/step - loss: 47.8720 - mae: 5.2527 - val_loss: 59.6245 - val_mae: 5.7637
# Epoch 12/100
# 18/18 [==============================] - 0s 4ms/step - loss: 47.3610 - mae: 5.3791 - val_loss: 56.4552 - val_mae: 5.5102
# Epoch 13/100
# 18/18 [==============================] - 0s 4ms/step - loss: 48.2067 - mae: 5.3397 - val_loss: 56.1290 - val_mae: 5.4923
# Epoch 14/100
# 18/18 [==============================] - 0s 4ms/step - loss: 46.9805 - mae: 5.3729 - val_loss: 55.9948 - val_mae: 5.5491
# Epoch 15/100
# 18/18 [==============================] - 0s 4ms/step - loss: 49.9091 - mae: 5.5035 - val_loss: 61.9820 - val_mae: 5.8396
# Epoch 16/100
# 18/18 [==============================] - 0s 4ms/step - loss: 46.0725 - mae: 5.1441 - val_loss: 55.9373 - val_mae: 5.6096
# Epoch 17/100
# 18/18 [==============================] - 0s 4ms/step - loss: 50.9845 - mae: 5.4919 - val_loss: 56.6160 - val_mae: 5.6119
# Epoch 18/100
# 18/18 [==============================] - 0s 4ms/step - loss: 54.5090 - mae: 5.5301 - val_loss: 57.0531 - val_mae: 5.5716
# Epoch 19/100
# 18/18 [==============================] - 0s 4ms/step - loss: 50.2172 - mae: 5.4219 - val_loss: 53.8128 - val_mae: 5.4359
# Epoch 20/100
# 18/18 [==============================] - 0s 4ms/step - loss:
# Epoch 74/100
# 18/18 [==============================] - 0s 4ms/step - loss: 42.8746 - mae: 4.9340 - val_loss: 46.8553 - val_mae: 5.1311
# Epoch 75/100
# 18/18 [==============================] - 0s 4ms/step - loss: 42.1846 - mae: 5.0007 - val_loss: 46.7020 - val_mae: 5.2746
# Epoch 76/100
# 18/18 [==============================] - 0s 4ms/step - loss: 44.5907 - mae: 5.1416 - val_loss: 51.7872 - val_mae: 5.4078
# Epoch 77/100
# 18/18 [==============================] - 0s 4ms/step - loss: 42.6197 - mae: 4.8101 - val_loss: 48.2231 - val_mae: 5.1879
# Epoch 78/100
# 18/18 [==============================] - 0s 4ms/step - loss: 49.5554 - mae: 5.2889 - val_loss: 44.8453 - val_mae: 5.1595
# Epoch 79/100
# 18/18 [==============================] - 0s 4ms/step - loss: 40.6605 - mae: 4.9383 - val_loss: 46.2237 - val_mae: 5.0884
# Epoch 80/100
# 18/18 [==============================] - 0s 4ms/step - loss: 44.6203 - mae: 5.1759 - val_loss: 45.9982 - val_mae: 5.1871
# Epoch 81/100
# 18/18 [==============================] - 0s 4ms/step - loss: 43.0989 - mae: 5.0105 - val_loss: 45.3664 - val_mae: 5.0455
# Epoch 82/100
# 18/18 [==============================] - 0s 4ms/step - loss: 43.7957 - mae: 5.0688 - val_loss: 50.3873 - val_mae: 5.2443
# Epoch 83/100
# 18/18 [==============================] - 0s 4ms/step - loss: 41.9713 - mae: 4.9953 - val_loss: 52.1401 - val_mae: 5.4371
# Epoch 84/100
# 18/18 [==============================] - 0s 4ms/step - loss: 44.0601 - mae: 5.0620 - val_loss: 45.6991 - val_mae: 5.1449
# Epoch 85/100
# 18/18 [==============================] - 0s 4ms/step - loss: 42.9685 - mae: 4.8305 - val_loss: 49.9258 - val_mae: 5.2488
# Epoch 86/100
# 18/18 [==============================] - 0s 4ms/step - loss: 44.8172 - mae: 5.0681 - val_loss: 45.6251 - val_mae: 5.2145
# Epoch 87/100
# 18/18 [==============================] - 0s 4ms/step - loss: 41.6354 - mae: 5.0713 - val_loss: 46.4033 - val_mae: 5.1214
# Epoch 88/100
# 18/18 [==============================] - 0s 4ms/step - loss: 40.3779 - mae: 4.9092 - val_loss: 45.3748 - val_mae: 5.1337
# Epoch 89/100
# 18/18 [==============================] - 0s 4ms/step - loss: 41.8115 - mae: 4.9667 - val_loss: 46.0784 - val_mae: 5.2031
# Epoch 90/100
# 18/18 [==============================] - 0s 4ms/step - loss: 45.0021 - mae: 5.2247 - val_loss: 48.2319 - val_mae: 5.2404
# Epoch 91/100
# 18/18 [==============================] - 0s 4ms/step - loss: 42.4815 - mae: 5.0543 - val_loss: 46.6526 - val_mae: 5.1167
# Epoch 92/100
# 18/18 [==============================] - 0s 4ms/step - loss: 39.5640 - mae: 4.8613 - val_loss: 48.9014 - val_mae: 5.1401
# Epoch 93/100
# 18/18 [==============================] - 0s 4ms/step - loss: 39.9614 - mae: 4.8902 - val_loss: 46.4928 - val_mae: 5.2317
# Epoch 94/100
# 18/18 [==============================] - 0s 4ms/step - loss: 42.4115 - mae: 5.0714 - val_loss: 45.8914 - val_mae: 5.1503
# Epoch 95/100
# 18/18 [==============================] - 0s 4ms/step - loss: 46.4038 - mae: 5.2975 - val_loss: 50.0779 - val_mae: 5.3109
# Epoch 96/100
# 18/18 [==============================] - 0s 4ms/step - loss: 38.2164 - mae: 4.6633 - val_loss: 49.7375 - val_mae: 5.2166
# Epoch 97/100
# 18/18 [==============================] - 0s 4ms/step - loss: 38.5893 - mae: 4.8359 - val_loss: 45.2645 - val_mae: 5.2102
# Epoch 98/100
# 18/18 [==============================] - 0s 4ms/step - loss: 46.0198 - mae: 5.2696 - val_loss: 48.4000 - val_mae: 5.2749
# Epoch 99/100
# 18/18 [==============================] - 0s 4ms/step - loss: 48.5074 - mae: 5.3565 - val_loss: 46.2426 - val_mae: 5.1777
# Epoch 100/100
# 18/18 [==============================] - 0s 4ms/step - loss: 38.6352 - mae: 4.7776 - val_loss: 54.6494 - val_mae: 5.5501

# %% [markdown]
# **Testing**

# %%
print(x_test.shape, np.asarray(y_test.shape) )
# Out:
# (309, 8) [309]

# %%
index = 10
# X_test.head()
ans = model.predict( x_test[index-1:index] )
print( ans, np.asarray(y_test[index-1:index]) )
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 576, 8) for input KerasTensor(type_spec=TensorSpec(shape=(None, 576, 8), dtype=tf.float32, name='dense_1_input'), name='dense_1_input', description="created by layer 'dense_1_input'"), but it was called on an input with incompatible shape (None, 8).
# [[37.69235]] [37.92]
