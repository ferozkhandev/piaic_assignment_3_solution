# %% [markdown]
# Assignment: Flowers Recognition <br>
# Dataset Description:<br>
#
# This dataset contains 4242 images of flowers.<br>
# The data collection is based on the data flicr, google images, yandex images.<br>
# You can use this datastet to recognize plants from the photo.<br>
#
# Attribute Information:<br>
# The pictures are divided into five classes: chamomile, tulip, rose, sunflower, dandelion.<br>
# For each class there are about 800 photos. Photos are not high resolution, about 320x240 pixels. <br>
# <b>Also explore how to resize images in tensorflow and then resize all the images to a same size. </b> <br>
# This is a Multiclass Classification Problem.<br>

# %% [markdown]
# WORKFLOW : <br>
# Load Data <br>
# Split into 60 and 40 ratio.<br>
# Encode labels.<br>
# Create Model<br>
# Compilation Step (Note : Its a Multiclass Classification problem , select loss , metrics according to it)<br>
# Train the Model.<br>
# If the model gets overfit tune your model by changing the units , No. of layers , epochs , add dropout layer or add Regularizer according to the need .<br>
# Prediction should be > 85%<br>
# Evaluation Step<br>
# Prediction<br>

# %% [markdown]
# Data : <br>
# https://drive.google.com/file/d/1-OX6wn5gA-bJpjPNfSyaYQLz-A-AB_uj/view?usp=sharing

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dense, Flatten, Dropout
from tensorflow.keras.preprocessing import image

# %%
flowers_dir = "C:\\Users\\meesn\\workspace\\piaic 3rd assignment\\Flowers Recognition\\flowers\\"

# %%
image_gen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.4,)

# %%
flowers_train = image_gen.flow_from_directory(flowers_dir, batch_size=32, target_size=(180, 180),subset= "training", color_mode="grayscale")
flowers_val = image_gen.flow_from_directory(flowers_dir, batch_size=32, target_size=(180, 180), subset= "validation", color_mode="grayscale")
# Out:
# Found 2597 images belonging to 5 classes.
# Found 1726 images belonging to 5 classes.

# %%
input_shape = (180, 180, 1)

models = Sequential()

models.add(Conv2D(30, 2, activation='relu', input_shape=input_shape))
models.add(MaxPooling2D())

models.add(Conv2D(30, 2, activation='relu', input_shape=input_shape))
models.add(MaxPooling2D())

models.add(Flatten())

models.add(Dense(16))
models.add(Activation('relu'))

models.add(Dense(10))
models.add(Activation('relu'))

models.add(Dense(8))
models.add(Activation('relu'))

models.add(Dropout(0.3))
models.add(Dense(5))
models.add(Activation('softmax'))

# %%
models.compile(optimizer='adam', loss="categorical_crossentropy", metrics=['accuracy'])

# %%
# models.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-cfb8acd20409> in <module>
# ----> 1 models.summary()
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\training.py in summary(self, line_length, positions, print_fn)
#    2374     """
#    2375     if not self.built:
# -> 2376       raise ValueError('This model has not yet been built. '
#    2377                        'Build the model first by calling `build()` or calling '
#    2378                        '`fit()` with some data, or specify '
#
# ValueError: This model has not yet been built. Build the model first by calling `build()` or calling `fit()` with some data, or specify an `input_shape` argument in the first layer(s) for automatic build.

# %%
results = models.fit_generator(flowers_train, epochs=10, validation_data=flowers_val)
# Out:
# Epoch 1/10
# 82/82 [==============================] - 73s 901ms/step - loss: 1.6043 - accuracy: 0.2430 - val_loss: 1.6031 - val_accuracy: 0.2433
# Epoch 2/10
# 82/82 [==============================] - 69s 835ms/step - loss: 1.6023 - accuracy: 0.2434 - val_loss: 1.6014 - val_accuracy: 0.2433
# Epoch 3/10
# 82/82 [==============================] - 70s 855ms/step - loss: 1.6011 - accuracy: 0.2434 - val_loss: 1.6004 - val_accuracy: 0.2433
# Epoch 4/10
# 82/82 [==============================] - 67s 819ms/step - loss: 1.6004 - accuracy: 0.2441 - val_loss: 1.5993 - val_accuracy: 0.2439
# Epoch 5/10
# 82/82 [==============================] - 66s 807ms/step - loss: 1.5996 - accuracy: 0.2434 - val_loss: 1.5994 - val_accuracy: 0.2433
# Epoch 6/10
# 82/82 [==============================] - 82s 1s/step - loss: 1.5993 - accuracy: 0.2434 - val_loss: 1.5991 - val_accuracy: 0.2433
# Epoch 7/10
# 82/82 [==============================] - 74s 904ms/step - loss: 1.5992 - accuracy: 0.2434 - val_loss: 1.5989 - val_accuracy: 0.2433
# Epoch 8/10
# 82/82 [==============================] - 75s 918ms/step - loss: 1.5990 - accuracy: 0.2434 - val_loss: 1.5988 - val_accuracy: 0.2433
# Epoch 9/10
# 82/82 [==============================] - 69s 835ms/step - loss: 1.5989 - accuracy: 0.2434 - val_loss: 1.5988 - val_accuracy: 0.2433
# Epoch 10/10
# 82/82 [==============================] - 73s 892ms/step - loss: 1.5989 - accuracy: 0.2434 - val_loss: 1.5987 - val_accuracy: 0.2433
