# %% [markdown]
# # Assignment: Ionosphere Data Problem
#
# ### Dataset Description:
#
# This radar data was collected by a system in Goose Bay, Labrador. This system consists of a phased array of 16 high-frequency antennas with a total transmitted power on the order of 6.4 kilowatts. See the paper for more details. The targets were free electrons in the ionosphere. "Good" radar returns are those showing evidence of some type of structure in the ionosphere. "Bad" returns are those that do not; their signals pass through the ionosphere.
#
# Received signals were processed using an autocorrelation function whose arguments are the time of a pulse and the pulse number. There were 17 pulse numbers for the Goose Bay system. Instances in this databse are described by 2 attributes per pulse number, corresponding to the complex values returned by the function resulting from the complex electromagnetic signal.
#
# ### Attribute Information:
#
# - All 34 are continuous
# - The 35th attribute is either "good" or "bad" according to the definition summarized above. This is a binary classification task.
#
#  <br><br>
#
# <table border="1"  cellpadding="6">
# 	<tbody>
#         <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Data Set Characteristics:&nbsp;&nbsp;</b></p></td>
# 		<td><p class="normal">Multivariate</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Instances:</b></p></td>
# 		<td><p class="normal">351</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Area:</b></p></td>
# 		<td><p class="normal">Physical</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#         <tr>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Attribute Characteristics:</b></p></td>
#             <td><p class="normal">Integer,Real</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Number of Attributes:</b></p></td>
#             <td><p class="normal">34</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Date Donated</b></p></td>
#             <td><p class="normal">N/A</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#     <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Associated Tasks:</b></p></td>
# 		<td><p class="normal">Classification</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Missing Values?</b></p></td>
# 		<td><p class="normal">N/A</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Web Hits:</b></p></td>
# 		<td><p class="normal">N/A</p></td>
# 	</tr>
#     </tbody>
#     </table>

# %% [markdown]
# ### WORKFLOW :
# - Load Data
# - Check Missing Values ( If Exist ; Fill each record with mean of its feature ) or any usless column.
# - Shuffle the data if needed.
# - Standardized the Input Variables. **Hint**: Centeralized the data
# - Split into 60 and 40 ratio.
# - Encode labels.
# - Model : 1 hidden layers including 16 unit.
# - Compilation Step (Note : Its a Binary problem , select loss , metrics according to it)
# - Train the Model with Epochs (100).
# - If the model gets overfit tune your model by changing the units , No. of layers , epochs , add dropout layer or add Regularizer according to the need .
# - Prediction should be > **92%**
# - Evaluation Step
# - Prediction

# %% [markdown]
# # Load Data:
# [Click Here to Download DataSet](https://github.com/ramsha275/ML_Datasets/blob/main/ionosphere_data.csv)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
df = pd.read_csv("/content/ionosphere_data.csv")
df.head()
# Out:
#    feature1  feature2  feature3  ...  feature33  feature34  label
# 0         1         0   0.99539  ...    0.18641   -0.45300      g
# 1         1         0   1.00000  ...   -0.13738   -0.02447      b
# 2         1         0   1.00000  ...    0.56045   -0.38238      g
# 3         1         0   1.00000  ...   -0.32382    1.00000      b
# 4         1         0   1.00000  ...   -0.04608   -0.65697      g
#
# [5 rows x 35 columns]

# %%
df['label'] = df['label'].replace(['g'], 1)
df['label'] = df['label'].replace(['b'], 0)
df.head()
# Out:
#    feature1  feature2  feature3  ...  feature33  feature34  label
# 0         1         0   0.99539  ...    0.18641   -0.45300      1
# 1         1         0   1.00000  ...   -0.13738   -0.02447      0
# 2         1         0   1.00000  ...    0.56045   -0.38238      1
# 3         1         0   1.00000  ...   -0.32382    1.00000      0
# 4         1         0   1.00000  ...   -0.04608   -0.65697      1
#
# [5 rows x 35 columns]

# %%
y = df['label']
df.drop('label', axis =1, inplace = True)
x = df.copy()

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4)

# %%
model = Sequential()
model.add(Dense(16, activation='relu', input_shape=(x_train.shape)))
model.add(Dense(1))

# %%
model.compile('rmsprop', loss='binary_crossentropy', metrics='acc')

# %%
model.fit(x_train, y_train, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Model was constructed with shape (None, 210, 34) for input KerasTensor(type_spec=TensorSpec(shape=(None, 210, 34), dtype=tf.float32, name='dense_input'), name='dense_input', description="created by layer 'dense_input'"), but it was called on an input with incompatible shape (None, 34).
# WARNING:tensorflow:Model was constructed with shape (None, 210, 34) for input KerasTensor(type_spec=TensorSpec(shape=(None, 210, 34), dtype=tf.float32, name='dense_input'), name='dense_input', description="created by layer 'dense_input'"), but it was called on an input with incompatible shape (None, 34).
# 7/7 [==============================] - 1s 3ms/step - loss: 9.2838 - acc: 0.3841
# Epoch 2/100
# 7/7 [==============================] - 0s 3ms/step - loss: 9.4119 - acc: 0.3733
# Epoch 3/100
# 7/7 [==============================] - 0s 2ms/step - loss: 8.9551 - acc: 0.4083
# Epoch 4/100
# 7/7 [==============================] - 0s 3ms/step - loss: 8.2936 - acc: 0.4370
# Epoch 5/100
# 7/7 [==============================] - 0s 4ms/step - loss: 8.7862 - acc: 0.4087
# Epoch 6/100
# 7/7 [==============================] - 0s 2ms/step - loss: 8.8508 - acc: 0.4093
# Epoch 7/100
# 7/7 [==============================] - 0s 3ms/step - loss: 8.9014 - acc: 0.4169
# Epoch 8/100
# 7/7 [==============================] - 0s 3ms/step - loss: 9.1561 - acc: 0.3861
# Epoch 9/100
# 7/7 [==============================] - 0s 3ms/step - loss: 8.4836 - acc: 0.4273
# Epoch 10/100
# 7/7 [==============================] - 0s 2ms/step - loss: 7.8082 - acc: 0.4655
# Epoch 11/100
# 7/7 [==============================] - 0s 2ms/step - loss: 8.4824 - acc: 0.4029
# Epoch 12/100
# 7/7 [==============================] - 0s 2ms/step - loss: 8.4438 - acc: 0.3856
# Epoch 13/100
# 7/7 [==============================] - 0s 2ms/step - loss: 7.8127 - acc: 0.4581
# Epoch 14/100
# 7/7 [==============================] - 0s 3ms/step - loss: 7.6264 - acc: 0.4804
# Epoch 15/100
# 7/7 [==============================] - 0s 2ms/step - loss: 7.9474 - acc: 0.4461
# Epoch 16/100
# 7/7 [==============================] - 0s 3ms/step - loss: 8.2078 - acc: 0.4334
# Epoch 17/100
# 7/7 [==============================] - 0s 3ms/step - loss: 8.3165 - acc: 0.4271
# Epoch 18/100
# 7/7 [==============================] - 0s 3ms/step - loss: 8.1037 - acc: 0.4411
# Epoch 19/100
# 7/7 [==============================] - 0s 3ms/step - loss: 7.9295 - acc: 0.4667
# Epoch 20/100
# 7/7 [==============================] - 0s 3ms/step - loss: 7.6602 - acc: 0.4486
# Epoch 21/100
# 7/7 [==============================] - 0s 3ms/step - loss: 8.0181 - acc: 0.4536
# Epoch 22/100
# 7/7 [==============================] - 0s 2ms/step - loss: 7.4744 - acc: 0.4902
# Epoch 23/100
# 7/7 [==============================] - 0s 3ms/step - loss: 8.0653 - acc: 0.4548
# Epoch 24/100
# 7/7 [==============================] - 0s 3ms/step - loss: 7.6359 - acc: 0.4838
# Epoch 25/100
# 7/7 [==============================] - 0s 4ms/step - loss: 7.5213 - acc: 0.4686
# Epoch 26/100
# 7/7 [==============================] - 0s 4ms/step - loss: 7.9761 - acc: 0.4483
# Epoch 27/100
# 7/7 [==============================] - 0s 4ms/step - loss: 7.3246 - acc: 0.4821
# Epoch 28/100
# 7/7 [==============================] - 0s 3ms/step - loss: 7.4921 - acc: 0.4691
# Epoch 29/100
# 7/7 [==============================] - 0s 3ms/step - loss: 6.7542 - acc: 0.5187
# Epoch 30/100
# 7/7 [==============================] - 0s 3ms/step - loss: 6.7354 - acc: 0.5281
# Epoch 31/100
# 7/7 [==============================] - 0s 3ms/step - loss: 6.7070 - acc: 0.5212
# Epoch 32/100
# 7/7 [==============================] - 0s 2ms/step - loss: 6.6503 - acc: 0.5246
# Epoch 33/100
# 7/7 [==============================] - 0s 2ms/step - loss: 6.3808 - acc: 0.5213
# Epoch 34/100
# 7/7 [==============================] - 0s 3ms/step - loss: 3.9078 - acc: 0.5520
# Epoch 35/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.7655 - acc: 0.4975
# Epoch 36/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0807 - acc: 0.5575
# Epoch 37/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.2570 - acc: 0.6237
# Epoch 38/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9260 - acc: 0.7433
# Epoch 39/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7806 - acc: 0.8285
# Epoch 40/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5280 - acc: 0.8670
# Epoch 41/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5048 - acc: 0.8833
# Epoch 42/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4423 - acc: 0.8701
# Epoch 43/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4384 - acc: 0.8691
# Epoch 44/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3291 - acc: 0.8758
# Epoch 45/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3341 - acc: 0.8817
# Epoch 46/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2579 - acc: 0.9247
# Epoch 47/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3694 - acc: 0.8919
# Epoch 48/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3741 - acc: 0.8820
# Epoch 49/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3457 - acc: 0.9038
# Epoch 50/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3170 - acc: 0.9124
# Epoch 51/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3887 - acc: 0.8987
# Epoch 52/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2062 - acc: 0.9381
# Epoch 53/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1883 - acc: 0.9374
# Epoch 54/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2100 - acc: 0.9363
# Epoch 55/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2641 - acc: 0.9537
# Epoch 56/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2197 - acc: 0.9508
# Epoch 57/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2052 - acc: 0.9588
# Epoch 58/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1248 - acc: 0.9546
# Epoch 59/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1302 - acc: 0.9552
# Epoch 60/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1745 - acc: 0.9597
# Epoch 61/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1416 - acc: 0.9745
# Epoch 62/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1881 - acc: 0.9619
# Epoch 63/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1999 - acc: 0.9639
# Epoch 64/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2445 - acc: 0.9664
# Epoch 65/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1472 - acc: 0.9774
# Epoch 66/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0988 - acc: 0.9743
# Epoch 67/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1130 - acc: 0.9544
# Epoch 68/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0867 - acc: 0.9761
# Epoch 69/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0938 - acc: 0.9688
# Epoch 70/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0662 - acc: 0.9840
# Epoch 71/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0704 - acc: 0.9770
# Epoch 72/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0871 - acc: 0.9759
# Epoch 73/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0809 - acc: 0.9691
# Epoch 74/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0631 - acc: 0.9807
# Epoch 75/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0765 - acc: 0.9669
# Epoch 76/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0779 - acc: 0.9647
# Epoch 77/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0819 - acc: 0.9529
# Epoch 78/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0738 - acc: 0.9682
# Epoch 79/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0639 - acc: 0.9750
# Epoch 80/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0709 - acc: 0.9814
# Epoch 81/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0679 - acc: 0.9581
# Epoch 82/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0675 - acc: 0.9753
# Epoch 83/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0556 - acc: 0.9735
# Epoch 84/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0390 - acc: 0.9877
# Epoch 85/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0426 - acc: 0.9853
# Epoch 86/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0588 - acc: 0.9784
# Epoch 87/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0529 - acc: 0.9773
# Epoch 88/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0593 - acc: 0.9680
# Epoch 89/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0399 - acc: 0.9847
# Epoch 90/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0615 - acc: 0.9866
# Epoch 91/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0438 - acc: 0.9800
# Epoch 92/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0472 - acc: 0.9931
# Epoch 93/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0482 - acc: 0.9878
# Epoch 94/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0536 - acc: 0.9754
# Epoch 95/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0527 - acc: 0.9853
# Epoch 96/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0427 - acc: 0.9897
# Epoch 97/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0368 - acc: 0.9905
# Epoch 98/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0298 - acc: 0.9955
# Epoch 99/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0437 - acc: 0.9843
# Epoch 100/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0325 - acc: 0.9879

# %% [markdown]
# **Testing**

# %%
print(x_test.shape, np.asarray(y_test.shape) )
# Out:
# (141, 34) [141]

# %%
model.predict( x_test)
# Out:
# array([[ 1.2238339 ],
#        [-1.166936  ],
#        [-2.3517017 ],
#        [-0.03671332],
#        [ 0.06689718],
#        [-0.38020062],
#        [ 1.1066476 ],
#        [ 1.1789024 ],
#        [-0.9786802 ],
#        [ 1.3057704 ],
#        [-1.6203052 ],
#        [-0.34556198],
#        [ 0.9823074 ],
#        [ 0.87383634],
#        [ 0.75035197],
#        [ 1.2708336 ],
#        [ 1.4078606 ],
#        [ 0.2689396 ],
#        [ 1.1448774 ],
#        [ 0.8320808 ],
#        [-0.47201627],
#        [-0.599561  ],
#        [ 1.2176993 ],
#        [ 1.1512828 ],
#        [-1.333477  ],
#        [-0.43114072],
#        [ 0.6830467 ],
#        [ 1.2050753 ],
#        [ 1.5236886 ],
#        [ 1.6886407 ],
#        [ 0.22884825],
#        [ 0.9261535 ],
#        [ 1.2569783 ],
#        [ 0.25205213],
#        [-0.11088184],
#        [ 1.4002113 ],
#        [ 0.56422037],
#        [ 1.3103336 ],
#        [ 1.3546038 ],
#        [-0.29116774],
#        [ 1.2764511 ],
#        [ 1.2157804 ],
#        [ 1.2416402 ],
#        [ 1.5515242 ],
#        [ 1.1899353 ],
#        [ 1.2322344 ],
#        [ 0.994825  ],
#        [ 1.2013422 ],
#        [ 0.7641438 ],
#        [-1.1234506 ],
#        [ 1.0086704 ],
#        [ 0.9421511 ],
#        [ 1.666577  ],
#        [ 0.734849  ],
#        [-0.3094105 ],
#        [ 1.2452163 ],
#        [ 1.3975567 ],
#        [ 0.57077867],
#        [ 1.326076  ],
#        [ 1.3522723 ],
#        [-0.03302011],
#        [ 1.2916975 ],
#        [ 0.22776358],
#        [ 1.2352391 ],
#        [-0.2524771 ],
#        [ 0.89567405],
#        [ 1.3685772 ],
#        [-0.01616634],
#        [ 1.1411704 ],
#        [ 0.01605177],
#        [ 1.3581526 ],
#        [ 1.1774617 ],
#        [ 0.64986044],
#        [ 0.48017454],
#        [ 1.5175601 ],
#        [ 0.8985387 ],
#        [ 0.08022372],
#        [ 1.27769   ],
#        [-0.669908  ],
#        [-0.8723454 ],
#        [-0.9058445 ],
#        [-0.38347417],
#        [-1.3197525 ],
#        [-0.5140733 ],
#        [ 0.41492826],
#        [-0.12544467],
#        [ 1.0902011 ],
#        [ 0.15873401],
#        [ 0.793997  ],
#        [ 0.44107217],
#        [ 1.2621764 ],
#        [ 0.5203105 ],
#        [ 1.1378968 ],
#        [ 1.2996389 ],
#        [ 1.3442662 ],
#        [ 1.2780529 ],
#        [-0.9049675 ],
#        [ 1.0914559 ],
#        [ 0.5197211 ],
#        [ 1.4896585 ],
#        [ 1.309078  ],
#        [-0.1942484 ],
#        [ 0.5975753 ],
#        [ 1.293014  ],
#        [ 0.94320726],
#        [-0.41820806],
#        [ 0.5732758 ],
#        [ 0.90989786],
#        [ 1.697377  ],
#        [ 1.1909509 ],
#        [-0.15534125],
#        [ 1.1327152 ],
#        [ 1.1305714 ],
#        [ 1.3524895 ],
#        [-0.03671332],
#        [ 1.5354182 ],
#        [ 0.83825207],
#        [ 0.60638577],
#        [ 1.133031  ],
#        [ 0.17453428],
#        [ 1.1691101 ],
#        [ 0.37885398],
#        [ 1.343178  ],
#        [ 1.3028284 ],
#        [ 1.2678161 ],
#        [-2.0542235 ],
#        [ 0.96624166],
#        [ 0.5929964 ],
#        [-0.16693367],
#        [ 1.2720021 ],
#        [ 1.1376059 ],
#        [ 1.4486678 ],
#        [-1.9290962 ],
#        [ 1.1576716 ],
#        [ 1.3408854 ],
#        [ 1.2933328 ],
#        [ 1.4296813 ],
#        [ 1.3599608 ],
#        [ 1.3179442 ],
#        [ 1.2186376 ],
#        [ 1.2723784 ]], dtype=float32)
