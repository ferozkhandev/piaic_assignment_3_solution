# %% [markdown]
# # Credit Card Fraud Detection::

# %% [markdown]
# Download dataset from this link:
#
# https://www.kaggle.com/mlg-ulb/creditcardfraud

# %% [markdown]
# # Description about dataset::

# %% [markdown]
# The datasets contains transactions made by credit cards in September 2013 by european cardholders.
# This dataset presents transactions that occurred in two days, where we have 492 frauds out of 284,807 transactions. The dataset is highly unbalanced, the positive class (frauds) account for 0.172% of all transactions.
#
# It contains only numerical input variables which are the result of a PCA transformation. Unfortunately, due to confidentiality issues, we cannot provide the original features and more background information about the data. Features V1, V2, … V28 are the principal components obtained with PCA, the only features which have not been transformed with PCA are 'Time' and 'Amount'. Feature 'Time' contains the seconds elapsed between each transaction and the first transaction in the dataset. The feature 'Amount' is the transaction Amount, this feature can be used for example-dependant cost-senstive learning.
#
#
# ### Feature 'Class' is the response variable and it takes value 1 in case of fraud and 0 otherwise.

# %% [markdown]
# # WORKFLOW :

# %% [markdown]
# 1.Load Data
#
# 2.Check Missing Values ( If Exist ; Fill each record with mean of its feature )
#
# 3.Standardized the Input Variables.
#
# 4.Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).
#
# 5.Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).
#
# 6.Compilation Step (Note : Its a Binary problem , select loss , metrics according to it)
#
# 7.Train the Model with Epochs (100).
#
# 8.If the model gets overfit tune your model by changing the units , No. of layers , epochs , add dropout layer or add Regularizer according to the need .
#
# 9.Prediction should be > 92%
# 10.Evaluation Step
# 11Prediction

# %% [markdown]
# # Task::

# %% [markdown]
# ## Identify fraudulent credit card transactions.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
df = pd.read_csv("/content/creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.drop('Time', axis =1, inplace = True)
df
# Out:
#                V1         V2        V3  ...       V28  Amount  Class
# 0       -1.359807  -0.072781  2.536347  ... -0.021053  149.62      0
# 1        1.191857   0.266151  0.166480  ...  0.014724    2.69      0
# 2       -1.358354  -1.340163  1.773209  ... -0.059752  378.66      0
# 3       -0.966272  -0.185226  1.792993  ...  0.061458  123.50      0
# 4       -1.158233   0.877737  1.548718  ...  0.215153   69.99      0
# ...           ...        ...       ...  ...       ...     ...    ...
# 284802 -11.881118  10.071785 -9.834783  ...  0.823731    0.77      0
# 284803  -0.732789  -0.055080  2.035030  ... -0.053527   24.79      0
# 284804   1.919565  -0.301254 -3.249640  ... -0.026561   67.88      0
# 284805  -0.240440   0.530483  0.702510  ...  0.104533   10.00      0
# 284806  -0.533413  -0.189733  0.703337  ...  0.013649  217.00      0
#
# [284807 rows x 30 columns]

# %%
df.fillna(df.mean)
# Out:
#                V1         V2        V3  ...       V28  Amount  Class
# 0       -1.359807  -0.072781  2.536347  ... -0.021053  149.62      0
# 1        1.191857   0.266151  0.166480  ...  0.014724    2.69      0
# 2       -1.358354  -1.340163  1.773209  ... -0.059752  378.66      0
# 3       -0.966272  -0.185226  1.792993  ...  0.061458  123.50      0
# 4       -1.158233   0.877737  1.548718  ...  0.215153   69.99      0
# ...           ...        ...       ...  ...       ...     ...    ...
# 284802 -11.881118  10.071785 -9.834783  ...  0.823731    0.77      0
# 284803  -0.732789  -0.055080  2.035030  ... -0.053527   24.79      0
# 284804   1.919565  -0.301254 -3.249640  ... -0.026561   67.88      0
# 284805  -0.240440   0.530483  0.702510  ...  0.104533   10.00      0
# 284806  -0.533413  -0.189733  0.703337  ...  0.013649  217.00      0
#
# [284807 rows x 30 columns]

# %%
y = df['Class']
df.drop('Class', axis =1, inplace = True)
x = df.copy()

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2)

# %%
model = Sequential()
model.add(Dense(10, activation='relu', input_shape=(x_train.shape)))
model.add(Dense(8, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile('rmsprop', loss='binary_crossentropy', metrics='acc')

# %%
model.fit(x_train, y_train, epochs=100, verbose=1, validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# WARNING:tensorflow:Model was constructed with shape (None, 159491, 29) for input KerasTensor(type_spec=TensorSpec(shape=(None, 159491, 29), dtype=tf.float32, name='dense_input'), name='dense_input', description="created by layer 'dense_input'"), but it was called on an input with incompatible shape (None, 29).
# WARNING:tensorflow:Model was constructed with shape (None, 159491, 29) for input KerasTensor(type_spec=TensorSpec(shape=(None, 159491, 29), dtype=tf.float32, name='dense_input'), name='dense_input', description="created by layer 'dense_input'"), but it was called on an input with incompatible shape (None, 29).
# 4966/4985 [============================>.] - ETA: 0s - loss: 0.2397 - acc: 0.9735WARNING:tensorflow:Model was constructed with shape (None, 159491, 29) for input KerasTensor(type_spec=TensorSpec(shape=(None, 159491, 29), dtype=tf.float32, name='dense_input'), name='dense_input', description="created by layer 'dense_input'"), but it was called on an input with incompatible shape (None, 29).
# 4985/4985 [==============================] - 8s 1ms/step - loss: 0.2391 - acc: 0.9735 - val_loss: 0.0368 - val_acc: 0.9990
# Epoch 2/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0441 - acc: 0.9991 - val_loss: 0.0185 - val_acc: 0.9992
# Epoch 3/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0267 - acc: 0.9992 - val_loss: 0.0188 - val_acc: 0.9993
# Epoch 4/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0272 - acc: 0.9992 - val_loss: 0.0130 - val_acc: 0.9993
# Epoch 5/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0229 - acc: 0.9991 - val_loss: 0.0405 - val_acc: 0.9992
# Epoch 6/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0658 - acc: 0.9992 - val_loss: 0.0080 - val_acc: 0.9994
# Epoch 7/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0183 - acc: 0.9993 - val_loss: 0.0096 - val_acc: 0.9994
# Epoch 8/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0259 - acc: 0.9990 - val_loss: 0.0073 - val_acc: 0.9994
# Epoch 9/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0183 - acc: 0.9991 - val_loss: 0.0059 - val_acc: 0.9994
# Epoch 10/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0369 - acc: 0.9989 - val_loss: 0.0125 - val_acc: 0.9993
# Epoch 11/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0243 - acc: 0.9991 - val_loss: 0.0120 - val_acc: 0.9993
# Epoch 12/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0284 - acc: 0.9991 - val_loss: 0.0079 - val_acc: 0.9993
# Epoch 13/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0221 - acc: 0.9992 - val_loss: 0.0067 - val_acc: 0.9993
# Epoch 14/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0308 - acc: 0.9985 - val_loss: 0.0133 - val_acc: 0.9993
# Epoch 15/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0202 - acc: 0.9991 - val_loss: 0.0076 - val_acc: 0.9993
# Epoch 16/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0225 - acc: 0.9990 - val_loss: 0.0068 - val_acc: 0.9993
# Epoch 17/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0186 - acc: 0.9989 - val_loss: 0.0053 - val_acc: 0.9993
# Epoch 18/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0208 - acc: 0.9989 - val_loss: 0.0061 - val_acc: 0.9993
# Epoch 19/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0143 - acc: 0.9990 - val_loss: 0.0057 - val_acc: 0.9993
# Epoch 20/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0337 - acc: 0.9990 - val_loss: 0.0105 - val_acc: 0.9993
# Epoch 21/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0171 - acc: 0.9989 - val_loss: 0.0050 - val_acc: 0.9992
# Epoch 22/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0152 - acc: 0.9991 - val_loss: 0.0444 - val_acc: 0.9990
# Epoch 23/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0368 - acc: 0.9986 - val_loss: 0.0071 - val_acc: 0.9993
# Epoch 24/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0296 - acc: 0.9986 - val_loss: 0.0226 - val_acc: 0.9993
# Epoch 25/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0228 - acc: 0.9988 - val_loss: 0.0047 - val_acc: 0.9993
# Epoch 26/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0241 - acc: 0.9988 - val_loss: 0.0077 - val_acc: 0.9994
# Epoch 27/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0404 - acc: 0.9990 - val_loss: 0.0053 - val_acc: 0.9994
# Epoch 28/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0266 - acc: 0.9990 - val_loss: 0.0053 - val_acc: 0.9994
# Epoch 29/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0270 - acc: 0.9988 - val_loss: 0.0053 - val_acc: 0.9994
# Epoch 30/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0213 - acc: 0.9988 - val_loss: 0.0097 - val_acc: 0.9994
# Epoch 31/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.
100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0116 - acc: 0.9994 - val_loss: 0.0075 - val_acc: 0.9994
# Epoch 68/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0101 - acc: 0.9995 - val_loss: 0.0056 - val_acc: 0.9994
# Epoch 69/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0085 - acc: 0.9994 - val_loss: 0.0071 - val_acc: 0.9995
# Epoch 70/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0126 - acc: 0.9993 - val_loss: 0.0075 - val_acc: 0.9994
# Epoch 71/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0116 - acc: 0.9993 - val_loss: 0.0064 - val_acc: 0.9994
# Epoch 72/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0084 - acc: 0.9993 - val_loss: 0.0084 - val_acc: 0.9993
# Epoch 73/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0136 - acc: 0.9993 - val_loss: 0.0130 - val_acc: 0.9995
# Epoch 74/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0201 - acc: 0.9992 - val_loss: 0.0097 - val_acc: 0.9995
# Epoch 75/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0121 - acc: 0.9992 - val_loss: 0.0129 - val_acc: 0.9994
# Epoch 76/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0159 - acc: 0.9992 - val_loss: 0.0110 - val_acc: 0.9994
# Epoch 77/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0153 - acc: 0.9992 - val_loss: 0.0076 - val_acc: 0.9995
# Epoch 78/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0103 - acc: 0.9993 - val_loss: 0.0090 - val_acc: 0.9993
# Epoch 79/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0086 - acc: 0.9994 - val_loss: 0.0093 - val_acc: 0.9995
# Epoch 80/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0103 - acc: 0.9992 - val_loss: 0.0065 - val_acc: 0.9995
# Epoch 81/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0099 - acc: 0.9994 - val_loss: 0.0119 - val_acc: 0.9993
# Epoch 82/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0173 - acc: 0.9993 - val_loss: 0.0119 - val_acc: 0.9995
# Epoch 83/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0194 - acc: 0.9993 - val_loss: 0.0053 - val_acc: 0.9995
# Epoch 84/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0114 - acc: 0.9992 - val_loss: 0.0119 - val_acc: 0.9995
# Epoch 85/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0138 - acc: 0.9993 - val_loss: 0.0085 - val_acc: 0.9995
# Epoch 86/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0129 - acc: 0.9994 - val_loss: 0.0081 - val_acc: 0.9994
# Epoch 87/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0137 - acc: 0.9994 - val_loss: 0.0095 - val_acc: 0.9995
# Epoch 88/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0153 - acc: 0.9993 - val_loss: 0.0056 - val_acc: 0.9995
# Epoch 89/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0135 - acc: 0.9993 - val_loss: 0.0061 - val_acc: 0.9995
# Epoch 90/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0118 - acc: 0.9994 - val_loss: 0.0065 - val_acc: 0.9994
# Epoch 91/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0151 - acc: 0.9994 - val_loss: 0.0061 - val_acc: 0.9994
# Epoch 92/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0145 - acc: 0.9994 - val_loss: 0.0079 - val_acc: 0.9994
# Epoch 93/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0153 - acc: 0.9994 - val_loss: 0.0098 - val_acc: 0.9994
# Epoch 94/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0201 - acc: 0.9992 - val_loss: 0.0075 - val_acc: 0.9994
# Epoch 95/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0157 - acc: 0.9994 - val_loss: 0.0067 - val_acc: 0.9994
# Epoch 96/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0129 - acc: 0.9993 - val_loss: 0.0080 - val_acc: 0.9993
# Epoch 97/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0126 - acc: 0.9993 - val_loss: 0.0086 - val_acc: 0.9994
# Epoch 98/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0161 - acc: 0.9993 - val_loss: 0.0069 - val_acc: 0.9994
# Epoch 99/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0115 - acc: 0.9994 - val_loss: 0.0094 - val_acc: 0.9994
# Epoch 100/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0129 - acc: 0.9993 - val_loss: 0.0064 - val_acc: 0.9995

# %%
pred = model.predict( x_test)
print(pred[0])
print(np.asarray(y_test)[0])
# Out:
# [3.7569987e-14]
# 0
